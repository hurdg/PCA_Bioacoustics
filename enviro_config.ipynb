# %%
#Create conda enviro, not a .venv (reccommended by tensorflow)
#NOTE:Run in powershell

# !conda create --name tf_gan python=3.9 #NOTE: v3.12 is not supported for tf < 2.11
# !conda activate tf_gan

#GPU setup 
#Test if GPU present with "nvidia-smi"
# !conda install -c conda-forge cudatoolkit=11.2 cudnn=8.1.0

#TensorFlow requires a recent version of pip, so upgrade your pip installation to be sure you're running the latest version.
# %pip install --upgrade pip

# Anything above 2.10 is not supported on the GPU on Windows Native
# %pip install "tensorflow<2.11" 

#Verify the GPU setup:
# %python -c "import tensorflow as tf; print(tf.config.list_physical_devices('GPU'))"

# %%
#%pip install tensorflow-gpu==2.5.0

# %pip install scipy
# %pip install matplotlib==3.0.2
# %pip install librosa==0.6.2
# Out:
# ...
#   Using cached tensorflow_gpu-2.5.0-cp39-cp39-win_amd64.whl.metadata (2.8 kB)
# ...
#   Using cached numpy-1.19.5-cp39-cp39-win_amd64.whl.metadata (2.0 kB)
# ...
#   Using cached absl_py-0.15.0-py3-none-any.whl.metadata (2.4 kB)
# ...
#   Using cached flatbuffers-1.12-py2.py3-none-any.whl.metadata (872 bytes)
# ...
#   Using cached h5py-3.1.0-cp39-cp39-win_amd64.whl.metadata (2.1 kB)
# ...
#   Using cached six-1.15.0-py2.py3-none-any.whl.metadata (1.8 kB)
# ...
#   Using cached termcolor-1.1.0-py3-none-any.whl
# ...
#   Using cached typing_extensions-3.7.4.3-py3-none-any.whl.metadata (2.0 kB)
# ...
#   Using cached wrapt-1.12.1-py3-none-any.whl
# ...
#   Using cached tensorflow_estimator-2.5.0-py2.py3-none-any.whl.metadata (1.2 kB)
# ...
#   Using cached keras_nightly-2.5.0.dev2021032900-py2.py3-none-any.whl.metadata (1.2 kB)
# ...
#   Using cached grpcio-1.34.1-cp39-cp39-win_amd64.whl.metadata (4.0 kB)
# ...
# Using cached tensorflow_gpu-2.5.0-cp39-cp39-win_amd64.whl (422.6 MB)
# Using cached absl_py-0.15.0-py3-none-any.whl (132 kB)
# ...

# %%
# !export CUDA_VISIBLE_DEVICES="0"
# !python train_wavegan.py train ./train \
	--data_dir "../data/positive/weto/"
# Out:
# 'export' is not recognized as an internal or external command,
# operable program or batch file.
# 2024-06-15 12:34:45.412993: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library cudart64_110.dll
# Traceback (most recent call last):
#   File "c:\Users\gavin hurd\.conda\envs\tf_gan\lib\site-packages\numpy\__init__.py", line 362, in __getattr__
#     raise AttributeError("module {!r} has no attribute "
# AttributeError: module 'numpy' has no attribute 'typeDict'
# c:\Users\gavin hurd\.conda\envs\tf_gan\lib\site-packages\tensorflow\python\framework\dtypes.py:511: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   np.object,
# Traceback (most recent call last):
#   File "Z:\EI Monitoring\Amphibian Acoustic Classifier\Analysis\GAN\train_wavegan.py", line 12, in <module>
#     import tensorflow as tf
# ...
